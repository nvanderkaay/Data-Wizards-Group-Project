# %%
import pandas as pd 
import numpy as np

# %%
car_sale = pd.read_csv('car_cleaned_data.csv')

# %%
car_sale.head()
# Out:
#    Unnamed: 0  Year    Make            Model Used/New  Price  ConsumerRating  \
# 0           0  2019  Toyota        Sienna SE     Used  39998             4.6
# 1           1  2018    Ford     F-150 Lariat     Used  49985             4.8
# 2           2  2017     RAM     1500 Laramie     Used  41860             4.7
# 3           3  2021   Honda  Accord Sport SE     Used  28500             5.0
# 4           4  2020   Lexus           RX 350     Used  49000             4.8
#
#    ConsumerReviews SellerType  \
# 0               45     Dealer
# 1              817     Dealer
# 2              495     Dealer
# 3               36     Dealer
# 4               76     Dealer
#
#                                           SellerName  ...  InteriorColor  \
# 0  CarMax Murrieta - Now offering Curbside Pickup...  ...          Black
# 1                                    Giant Chevrolet  ...          Black
# 2                             Gill Auto Group Madera  ...          Black
# ...

# %%
car_sale[car_sale['FuelType'] == 'Gasoline']
# Out:
#       Unnamed: 0  Year     Make                   Model Used/New  Price  \
# 0              0  2019   Toyota               Sienna SE     Used  39998
# 1              1  2018     Ford            F-150 Lariat     Used  49985
# 2              2  2017      RAM            1500 Laramie     Used  41860
# 3              3  2021    Honda         Accord Sport SE     Used  28500
# 4              4  2020    Lexus                  RX 350     Used  49000
# ...          ...   ...      ...                     ...      ...    ...
# 8466        9373  2019    Honda               CR-V EX-L     Used  31999
# 8467        9374  2019   Subaru  Crosstrek 2.0i Premium     Used  27374
# 8468        9376  2017    Buick         Enclave Leather     Used  26944
# 8469        9377  2019   Subaru        Forester Premium     Used  28568
# 8470        9378  2019  Hyundai   Santa Fe Ultimate 2.4     Used  32091
#
#       ConsumerRating  ConsumerReviews SellerType  \
# 0                4.6               45     Dealer
# ...

# %%
car_sale['FuelType'].unique()
# Out:
# array(['Gasoline', 'Gasoline Fuel', 'E85 Flex Fuel',
#        'Electric Fuel System', 'Electric', 'Hybrid', '–',
#        'Flex Fuel Capability', 'Diesel', 'Gasoline/Mild Electric Hybrid',
#        'Flexible Fuel'], dtype=object)

# %%
car_sale[car_sale['FuelType'] == 'Electric']['Price'].describe()
# Out:
# count       131.000000
# mean      67825.770992
# std       18586.422302
# min       20992.000000
# 25%       58492.500000
# 50%       69888.000000
# 75%       72994.500000
# max      173987.000000
# Name: Price, dtype: float64

# %%
car_sale[car_sale['FuelType'] == 'Gasoline']['Price'].describe()
# Out:
# count      8063.000000
# mean      39439.686221
# std       20692.210319
# min        3995.000000
# 25%       28990.000000
# 50%       35998.000000
# 75%       45306.500000
# max      449996.000000
# Name: Price, dtype: float64

# %% [markdown]
# Gas cars are usually more expensive than electric cars

# %%
gas_max = car_sale[car_sale['FuelType'] == 'Gasoline']['MaxMPG'].mean()

# %%
gas_min = car_sale[car_sale['FuelType'] == 'Gasoline']['MinMPG'].mean()

# %%
electric_max = car_sale[car_sale['FuelType'] == 'Electric']['MaxMPG'].mean()

# %%
electric_min = car_sale[car_sale['FuelType'] == 'Electric']['MinMPG'].mean()

# %%
print('For gas cars the avg maxmpg is',gas_max,'and the avg minmpg is',gas_min)
# Out:
# For gas cars the avg maxmpg is 27.85241225350366 and the avg minmpg is 20.936003968746125

# %%
print('For electric cars the avg maxmpg is',electric_max,'and the avg minmpg is',electric_min)
# Out:
# For electric cars the avg maxmpg is 118.22900763358778 and the avg minmpg is 107.59541984732824

# %% [markdown]
# Electric cars have a high MPG
