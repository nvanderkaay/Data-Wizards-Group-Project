# %% [markdown]
# Over the past week I have been cleaning the data
#
#
# Found problems with the MPG where the min and max are switch for some rows. Initially I had a problem where it only fix the Max but to fixed that I put the min and max into variables so it doesn't change the data.
#
# Found that for some rows the min and max MPG both 0 so I remove them.
# There were some duplicates so I used .duplicates().sum() to see how many there were.

# %%
import pandas as pd
import numpy as np

# %%
car_sale = pd.read_csv('Online_Cars_Sale_Marketplace.csv')

# %%
car_sale = car_sale[car_sale['Price'] != 'Not Priced'] ## remove 'Not Priced' rows
car_sale['Price'] = car_sale['Price'].replace(r'[,$]', '', regex=True)  ## remove special characters $ and , 
car_sale['Price'] = car_sale['Price'].astype(int) 
car_sale['Used/New'] = car_sale['Used/New'].replace(r'.*Certified.*', 'Certified', regex=True) ## change all Certified to just Certified
car_sale[car_sale['Drivetrain'] != "-"] ## remove "-" in Drivetrain column
Min = car_sale['MinMPG']
Max = car_sale['MaxMPG']
car_sale['MaxMPG'] = np.maximum(Min, Max)
car_sale['MinMPG'] = np.minimum(Min, Max) ## Fix the min and max being in the wrong column
car_sale.drop(car_sale[(car_sale['MinMPG'] == 0)&(car_sale['MaxMPG'] == 0)].index, inplace = True) ## remove rows where min and max MPG are 0 
car_sale = car_sale.drop_duplicates() ## remove duplicates
car_sale
# Out:
#       Year     Make                   Model Used/New  Price  ConsumerRating  \
# 0     2019   Toyota               Sienna SE     Used  39998             4.6
# 1     2018     Ford            F-150 Lariat     Used  49985             4.8
# 2     2017      RAM            1500 Laramie     Used  41860             4.7
# 3     2021    Honda         Accord Sport SE     Used  28500             5.0
# 4     2020    Lexus                  RX 350     Used  49000             4.8
# ...    ...      ...                     ...      ...    ...             ...
# 9373  2019    Honda               CR-V EX-L     Used  31999             4.8
# 9374  2019   Subaru  Crosstrek 2.0i Premium     Used  27374             4.7
# 9376  2017    Buick         Enclave Leather     Used  26944             4.8
# 9377  2019   Subaru        Forester Premium     Used  28568             4.7
# 9378  2019  Hyundai   Santa Fe Ultimate 2.4     Used  32091             4.8
#
#       ConsumerReviews SellerType  \
# 0                  45     Dealer
# 1                 817     Dealer
# 2                 495     Dealer
# 3                  36     Dealer
# 4                  76     Dealer
# ...               ...        ...
# 9373              540     Dealer
# 9374              205     Dealer
# 9376              137     Dealer
# 9377              279     Dealer
# 9378              204     Dealer
#
#                                              SellerName  SellerRating  ...  \
# 0     CarMax Murrieta - Now offering Curbside Pickup...           3.3  ...
# 1                                       Giant Chevrolet           4.8  ...
# 2                                Gill Auto Group Madera           4.6  ...
# 3                                   AutoSavvy Las Vegas           4.6  ...
# 4                                    Lexus of Henderson           4.8  ...
# ...                                                 ...           ...  ...
# 9373                                      Hoffman Honda           4.8  ...
# 9374                 Bertera Subaru of West Springfield           4.4  ...
# 9376                            Tulley Automotive Group           4.7  ...
# 9377                                         Ira Subaru           4.4  ...
# 9378                                   Route 44 Hyundai           4.4  ...
#
#       InteriorColor         Drivetrain MinMPG MaxMPG  FuelType  \
# 0             Black  Front-wheel Drive     19     27  Gasoline
# 1             Black   Four-wheel Drive     19     24  Gasoline
# 2             Black   Four-wheel Drive     15     21  Gasoline
# 3                 –  Front-wheel Drive     29     35  Gasoline
# 4             Birch  Front-wheel Drive     20     27  Gasoline
# ...             ...                ...    ...    ...       ...
# 9373              –    All-wheel Drive     27     33  Gasoline
# 9374           Gray    All-wheel Drive     27     33  Gasoline
# 9376          Ebony    All-wheel Drive     15     22  Gasoline
# 9377          Black    All-wheel Drive     26     33  Gasoline
# 9378          Black    All-wheel Drive     21     27  Gasoline
#
#             Transmission                           Engine                VIN  \
# 0      8-Speed Automatic             3.5L V6 24V PDI DOHC  5TDXZ3DC2KS015402
# 1     10-Speed Automatic  3.5L V6 24V PDI DOHC Twin Turbo  1FTEW1EG2JFD44217
# 2      8-Speed Automatic             5.7L V8 16V MPFI OHV  1C6RR7VT5HS842283
# 3          Automatic CVT       1.5L I4 16V GDI DOHC Turbo  1HGCV1F49MA038035
# 4      8-Speed Automatic             3.5L V6 24V PDI DOHC  2T2AZMAA8LC156270
# ...                  ...                              ...                ...
# 9373       Automatic CVT       1.5L I4 16V GDI DOHC Turbo  2HKRW2H87KH643043
# 9374       Automatic CVT             2.0L H4 16V GDI DOHC  JF2GTADC4KH318032
# 9376   6-Speed Automatic             3.6L V6 24V GDI DOHC  5GAKVBKD4HJ190334
# 9377       Automatic CVT             2.5L H4 16V GDI DOHC  JF2SKAGC9KH423450
# 9378   8-Speed Automatic             2.4L I4 16V GDI DOHC  5NMS5CAD1KH002128
#
#          Stock#  Mileage
# 0      22998646    29403
# 1        22418A    32929
# 2     NG277871G    23173
# 3         54237    10598
# 4      HDT4181A    28137
# ...         ...      ...
# 9373    10553HB    44481
# 9374    220502A    15606
# 9376   B221381B    62649
# 9377   KH423450    30760
# 9378     H48345    41645
#
# [8471 rows x 32 columns]

# %%
car_sale[(car_sale['MinMPG'] == 0)&(car_sale['MaxMPG'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Year, Make, Model, Used/New, Price, ConsumerRating, ConsumerReviews, SellerType, SellerName, SellerRating, SellerReviews, StreetName, State, Zipcode, DealType, ComfortRating, InteriorDesignRating, PerformanceRating, ValueForMoneyRating, ExteriorStylingRating, ReliabilityRating, ExteriorColor, InteriorColor, Drivetrain, MinMPG, MaxMPG, FuelType, Transmission, Engine, VIN, Stock#, Mileage]
# Index: []
#
# [0 rows x 32 columns]

# %%
car_sale['Price'].dtypes
# Out:
# dtype('int64')
