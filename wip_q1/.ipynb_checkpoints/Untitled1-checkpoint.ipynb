# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('Online_Cars_Sale_Marketplace.csv')

# Remove duplicate VINs (keep first occurrence)
if 'VIN' in df.columns:
    df = df.drop_duplicates(subset='VIN', keep='first')

# Fill missing consumer reviews and ratings with 0
df[['ConsumerReviews', 'ConsumerRating']] = df[['ConsumerReviews', 'ConsumerRating']].fillna(0)

# Define how to group cars (Make, Model, Year)
group_cols = ['Make', 'Model', 'Year']

# Group the data
car_summary = df.groupby(group_cols).agg({
    'ConsumerReviews': 'sum',
    'ConsumerRating': 'mean'
}).reset_index()

# Add number of listings
car_summary['Num_Listings'] = df.groupby(group_cols).size().values

# Add square root of number of listings
car_summary['Sqrt_Listings'] = np.sqrt(car_summary['Num_Listings'])

# Calculate the Popularity Score
car_summary['Popularity_Score'] = (
    car_summary['ConsumerReviews'] *
    car_summary['ConsumerRating'] *
    car_summary['Sqrt_Listings']
)

# Sort by popularity score and get top 10
top_cars = car_summary.sort_values(by='Popularity_Score', ascending=False).head(10)

# Display the top 10
print(top_cars)

# (Optional) Plot the results
plt.figure(figsize=(12,6))
plt.barh(top_cars['Make'] + ' ' + top_cars['Model'] + ' ' + top_cars['Year'].astype(str), top_cars['Popularity_Score'])
plt.xlabel('Popularity Score')
plt.title('Top 10 Most Popular Car Listings (After Removing Duplicate VINs)')
plt.gca().invert_yaxis()  # Highest on top
plt.tight_layout()
plt.show()
# Out:
#           Make                   Model  Year  ConsumerReviews  ConsumerRating  \
# 957      Honda               CR-V EX-L  2019            67500             4.8
# 952      Honda                 CR-V EX  2019            30240             4.8
# 1236      Jeep  Grand Cherokee Limited  2019            21280             4.8
# 2284    Toyota                 RAV4 LE  2018            23870             4.8
# 1195      Jeep        Cherokee Limited  2019            21016             4.6
# 2300    Toyota                RAV4 XLE  2018            20790             4.8
# 1022     Honda              Pilot EX-L  2019            10927             4.8
# 451   Cadillac              XT5 Luxury  2019             7990             4.6
# 1235      Jeep  Grand Cherokee Limited  2018            11850             4.8
# 1616     Mazda      CX-5 Grand Touring  2019             9890             4.8
#
#       Num_Listings  Sqrt_Listings  Popularity_Score
# 957            125      11.180340      3.622430e+06
# 952             56       7.483315      1.086218e+06
# 1236            95       9.746794      9.955766e+05
# 2284            31       5.567764      6.379322e+05
# 1195            37       6.082763      5.880426e+05
# 2300            27       5.196152      5.185344e+05
# 1022            49       7.000000      3.671472e+05
# 451             85       9.219544      3.388551e+05
# 1235            30       5.477226      3.115446e+05
# 1616            43       6.557439      3.112947e+05

# %%
df
# Out:
#       Year     Make                   Model Used/New    Price  ConsumerRating  \
# 0     2019   Toyota               Sienna SE     Used  39998.0             4.6
# 1     2018     Ford            F-150 Lariat     Used  49985.0             4.8
# 2     2017      RAM            1500 Laramie     Used  41860.0             4.7
# 3     2021    Honda         Accord Sport SE     Used  28500.0             5.0
# 4     2020    Lexus                  RX 350     Used  49000.0             4.8
# ...    ...      ...                     ...      ...      ...             ...
# 9374  2019   Subaru  Crosstrek 2.0i Premium     Used  27374.0             4.7
# 9375  2019     Audi         Q8 3.0T Premium     Used  61998.0             4.8
# 9376  2017    Buick         Enclave Leather     Used  26944.0             4.8
# 9377  2019   Subaru        Forester Premium     Used  28568.0             4.7
# 9378  2019  Hyundai   Santa Fe Ultimate 2.4     Used  32091.0             4.8
#
#       ConsumerReviews SellerType  \
# 0                  45     Dealer
# 1                 817     Dealer
# 2                 495     Dealer
# 3                  36     Dealer
# 4                  76     Dealer
# ...               ...        ...
# 9374              205     Dealer
# 9375               27     Dealer
# 9376              137     Dealer
# 9377              279     Dealer
# 9378              204     Dealer
#
#                                              SellerName  SellerRating  ...  \
# 0     CarMax Murrieta - Now offering Curbside Pickup...           3.3  ...
# 1                                       Giant Chevrolet           4.8  ...
# 2                                Gill Auto Group Madera           4.6  ...
# 3                                   AutoSavvy Las Vegas           4.6  ...
# 4                                    Lexus of Henderson           4.8  ...
# ...                                                 ...           ...  ...
# 9374                 Bertera Subaru of West Springfield           4.4  ...
# 9375                           Autobahn USA Westborough           4.8  ...
# 9376                            Tulley Automotive Group           4.7  ...
# 9377                                         Ira Subaru           4.4  ...
# 9378                                   Route 44 Hyundai           4.4  ...
#
#       InteriorColor         Drivetrain MinMPG MaxMPG  FuelType  \
# 0             Black  Front-wheel Drive     19     27  Gasoline
# 1             Black   Four-wheel Drive     19     24  Gasoline
# 2             Black   Four-wheel Drive     15     21  Gasoline
# 3                 –  Front-wheel Drive     29     35  Gasoline
# 4             Birch  Front-wheel Drive     20     27  Gasoline
# ...             ...                ...    ...    ...       ...
# 9374           Gray    All-wheel Drive     27     33  Gasoline
# 9375          Black    All-wheel Drive     17     22    Hybrid
# 9376          Ebony    All-wheel Drive     15     22  Gasoline
# 9377          Black    All-wheel Drive     26     33  Gasoline
# 9378          Black    All-wheel Drive     21     27  Gasoline
#
#             Transmission                             Engine  \
# 0      8-Speed Automatic               3.5L V6 24V PDI DOHC
# 1     10-Speed Automatic    3.5L V6 24V PDI DOHC Twin Turbo
# 2      8-Speed Automatic               5.7L V8 16V MPFI OHV
# 3          Automatic CVT         1.5L I4 16V GDI DOHC Turbo
# 4      8-Speed Automatic               3.5L V6 24V PDI DOHC
# ...                  ...                                ...
# 9374       Automatic CVT               2.0L H4 16V GDI DOHC
# 9375   8-Speed Automatic  3.0L V6 24V GDI DOHC Turbo Hybrid
# 9376   6-Speed Automatic               3.6L V6 24V GDI DOHC
# 9377       Automatic CVT               2.5L H4 16V GDI DOHC
# 9378   8-Speed Automatic               2.4L I4 16V GDI DOHC
#
#                     VIN     Stock#  Mileage
# 0     5TDXZ3DC2KS015402   22998646    29403
# 1     1FTEW1EG2JFD44217     22418A    32929
# 2     1C6RR7VT5HS842283  NG277871G    23173
# 3     1HGCV1F49MA038035      54237    10598
# 4     2T2AZMAA8LC156270   HDT4181A    28137
# ...                 ...        ...      ...
# 9374  JF2GTADC4KH318032    220502A    15606
# 9375  WA1AVAF14KD015389     AB4719    46855
# 9376  5GAKVBKD4HJ190334   B221381B    62649
# 9377  JF2SKAGC9KH423450   KH423450    30760
# 9378  5NMS5CAD1KH002128     H48345    41645
#
# [9379 rows x 32 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the fresh data
file_path = 'Online_Cars_Sale_Marketplace.csv'
df = pd.read_csv(file_path)

# Step 2: Clean the 'Price' column
df['Price'] = df['Price'].replace({r'\$': '', ',': '', 'Not Priced': None}, regex=True)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# Step 3: Group by Year, Make, Model
grouped = df.groupby(['Year', 'Make', 'Model']).agg({
    'ConsumerRating': 'mean',       # average rating
    'ConsumerReviews': 'sum',        # total reviews
    'Price': 'mean',                 # average price
    'Mileage': 'mean',               # average mileage
    'VIN': 'count'                   # number of listings
}).reset_index()

# Step 4: Rename VIN to Listings
grouped = grouped.rename(columns={'VIN': 'Listings'})

# Step 5: Create Sqrt Adjusted Popularity Score
grouped['SqrtListings'] = np.sqrt(grouped['Listings'])
grouped['SqrtAdjustedPopularity'] = grouped['ConsumerRating'] * grouped['ConsumerReviews'] * grouped['SqrtListings']

# Step 6: Sort by the new Sqrt Adjusted Popularity Score
grouped_sorted_sqrt = grouped.sort_values(by='SqrtAdjustedPopularity', ascending=False)

# Step 7: Select Top 10
top10_sqrt = grouped_sorted_sqrt.head(10).copy()

# Step 8: Create a readable label
top10_sqrt['CarLabel'] = (
    top10_sqrt['Year'].astype(str) + ' ' +
    top10_sqrt['Make'] + ' ' +
    top10_sqrt['Model']
)

# Step 9: Plot
plt.figure(figsize=(10,6))
plt.barh(top10_sqrt['CarLabel'], top10_sqrt['SqrtAdjustedPopularity'])
plt.gca().invert_yaxis()
plt.xlabel('Sqrt Adjusted Popularity Score (Rating × Reviews × sqrt(Listings))')
plt.title('Top 10 Most Popular Cars by Sqrt Adjusted Popularity')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Step 10: Display Top 10 Table
print("Top 10 Cars by Square Root Listings Adjusted Popularity Score:")
print(top10_sqrt[['Year', 'Make', 'Model', 'SqrtAdjustedPopularity']])
# Out:
# Top 10 Cars by Square Root Listings Adjusted Popularity Score:
#       Year      Make                   Model  SqrtAdjustedPopularity
# 1336  2019     Honda               CR-V EX-L            4.761808e+06
# 1335  2019     Honda                 CR-V EX            1.296122e+06
# 1390  2019      Jeep  Grand Cherokee Limited            1.206771e+06
# 1144  2018    Toyota                RAV4 XLE            7.327407e+05
# 1384  2019      Jeep        Cherokee Limited            7.111809e+05
# 1141  2018    Toyota                 RAV4 LE            7.006528e+05
# 1350  2019     Honda              Pilot EX-L            4.974770e+05
# 1252  2019  Cadillac              XT5 Luxury            4.520032e+05
# 1467  2019     Mazda      CX-5 Grand Touring            4.139750e+05
# 1023  2018      Jeep  Grand Cherokee Limited            3.272509e+05

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Load the data
file_path = 'Online_Cars_Sale_Marketplace.csv'
df = pd.read_csv(file_path)

# Step 2: Filter for California
df_ca = df[df['State'] == 'CA']

# Step 3: Group by Year, Make, Model within California
grouped_ca = df_ca.groupby(['Year', 'Make', 'Model']).agg({
    'ConsumerRating': 'mean',        # average rating
    'ConsumerReviews': 'sum',        # total reviews
    'VIN': 'count'                   # number of listings
}).reset_index()

# Step 4: Rename VIN to Listings
grouped_ca = grouped_ca.rename(columns={'VIN': 'Listings'})

# Step 5: Calculate Sqrt Adjusted Popularity Score
grouped_ca['SqrtListings'] = np.sqrt(grouped_ca['Listings'])
grouped_ca['SqrtAdjustedPopularity'] = (
    grouped_ca['ConsumerRating'] * 
    grouped_ca['ConsumerReviews'] * 
    grouped_ca['SqrtListings']
)

# Step 6: Sort and select Top 10
top10_ca = grouped_ca.sort_values(by='SqrtAdjustedPopularity', ascending=False).head(10).copy()

# Step 7: Create a readable car label
top10_ca['CarLabel'] = (
    top10_ca['Year'].astype(str) + ' ' + 
    top10_ca['Make'] + ' ' + 
    top10_ca['Model']
)

# Step 8: Plot the results
plt.figure(figsize=(10,6))
plt.barh(top10_ca['CarLabel'], top10_ca['SqrtAdjustedPopularity'])
plt.gca().invert_yaxis()
plt.xlabel('Sqrt Adjusted Popularity Score (Rating × Reviews × √Listings)')
plt.title('Top 10 Most Popular Car Types in California')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Step 9: Display the Top 10 table
print("Top 10 Car Types in California by Popularity Score:")
print(top10_ca[['Year', 'Make', 'Model', 'SqrtAdjustedPopularity']])
# Out:
# Top 10 Car Types in California by Popularity Score:
#      Year    Make               Model  SqrtAdjustedPopularity
# 220  2019  Toyota        RAV4 Limited            16339.200000
# 184  2019   Mazda  CX-5 Grand Touring            16225.420056
# 146  2019     BMW        X5 xDrive40i            15017.492925
# 145  2019     BMW        X3 xDrive30i            12563.100000
# 250  2020    Ford        Explorer XLT            12477.259314
# 120  2018  Toyota             RAV4 LE            10453.866653
# 122  2018  Toyota            RAV4 XLE            10453.866653
# 108  2018   Mazda  CX-5 Grand Touring            10368.000000
# 182  2019   Lexus          RX 350 350             9067.518893
# 218  2019  Toyota      Highlander XLE             8676.535315

# %%
import pandas as pd

# Set display option to show all columns when printing
pd.set_option('display.max_columns', None)

# Load the dataset
df_trim_analysis = pd.read_csv('Online_Cars_Sale_Marketplace.csv')

# Option 1: Display the first few rows with all columns visible
print(df_trim_analysis.head())

# Option 2: Print a full list of all column names
print("All column names:")
print(list(df_trim_analysis.columns))

# Option 3: Display the first row with all column values (for structure inspection)
print("First row, all columns:")
print(df_trim_analysis.iloc[0])
# Out:
#    Year    Make            Model Used/New     Price  ConsumerRating  \
# 0  2019  Toyota        Sienna SE     Used  $39,998              4.6
# 1  2018    Ford     F-150 Lariat     Used  $49,985              4.8
# 2  2017     RAM     1500 Laramie     Used  $41,860              4.7
# 3  2021   Honda  Accord Sport SE     Used  $28,500              5.0
# 4  2020   Lexus           RX 350     Used  $49,000              4.8
#
#    ConsumerReviews SellerType  \
# 0               45     Dealer
# 1              817     Dealer
# 2              495     Dealer
# 3               36     Dealer
# 4               76     Dealer
#
#                                           SellerName  SellerRating  \
# 0  CarMax Murrieta - Now offering Curbside Pickup...           3.3
# 1                                    Giant Chevrolet           4.8
# 2                             Gill Auto Group Madera           4.6
# 3                                AutoSavvy Las Vegas           4.6
# 4                                 Lexus of Henderson           4.8
#
#    SellerReviews                     StreetName State Zipcode DealType  \
# 0              3     25560 Madison Ave Murrieta    CA   92562    Great
# 1            131  1001 S Ben Maddox Way Visalia    CA   93292     Good
# 2            249       1100 S Madera Ave Madera    CA   93637     Good
# 3            284    2121 E Sahara Ave Las Vegas    NV   89104      NaN
# 4           4755     7737 Eastgate Rd Henderson    NV   89011     Good
#
#    ComfortRating  InteriorDesignRating  PerformanceRating  \
# 0            4.7                   4.6                4.6
# 1            4.9                   4.8                4.8
# 2            4.8                   4.7                4.8
# 3            4.9                   5.0                4.9
# 4            4.9                   4.8                4.8
#
#    ValueForMoneyRating  ExteriorStylingRating  ReliabilityRating  \
# 0                  4.4                    4.6                4.7
# 1                  4.6                    4.8                4.7
# 2                  4.6                    4.8                4.7
# 3                  5.0                    5.0                5.0
# 4                  4.7                    4.8                4.9
#
#                         ExteriorColor InteriorColor         Drivetrain  \
# 0                                 Red         Black  Front-wheel Drive
# 1                        Shadow Black         Black   Four-wheel Drive
# 2  Granite Crystal Clearcoat Metallic         Black   Four-wheel Drive
# 3                                Gray             –  Front-wheel Drive
# 4                 Eminent White Pearl         Birch  Front-wheel Drive
#
#    MinMPG  MaxMPG  FuelType        Transmission  \
# 0      19      27  Gasoline   8-Speed Automatic
# 1      19      24  Gasoline  10-Speed Automatic
# 2      15      21  Gasoline   8-Speed Automatic
# 3      29      35  Gasoline       Automatic CVT
# 4      20      27  Gasoline   8-Speed Automatic
#
#                             Engine                VIN     Stock#  Mileage
# 0             3.5L V6 24V PDI DOHC  5TDXZ3DC2KS015402   22998646    29403
# 1  3.5L V6 24V PDI DOHC Twin Turbo  1FTEW1EG2JFD44217     22418A    32929
# 2             5.7L V8 16V MPFI OHV  1C6RR7VT5HS842283  NG277871G    23173
# 3       1.5L I4 16V GDI DOHC Turbo  1HGCV1F49MA038035      54237    10598
# 4             3.5L V6 24V PDI DOHC  2T2AZMAA8LC156270   HDT4181A    28137
# All column names:
# ['Year', 'Make', 'Model', 'Used/New', 'Price', 'ConsumerRating', 'ConsumerReviews', 'SellerType', 'SellerName', 'SellerRating', 'SellerReviews', 'StreetName', 'State', 'Zipcode', 'DealType', 'ComfortRating', 'InteriorDesignRating', 'PerformanceRating', 'ValueForMoneyRating', 'ExteriorStylingRating', 'ReliabilityRating', 'ExteriorColor', 'InteriorColor', 'Drivetrain', 'MinMPG', 'MaxMPG', 'FuelType', 'Transmission', 'Engine', 'VIN', 'Stock#', 'Mileage']
# First row, all columns:
# Year                                                                  2019
# Make                                                                Toyota
# Model                                                            Sienna SE
# Used/New                                                              Used
# Price                                                             $39,998
# ConsumerRating                                                         4.6
# ConsumerReviews                                                         45
# SellerType                                                          Dealer
# SellerName               CarMax Murrieta - Now offering Curbside Pickup...
# SellerRating                                                           3.3
# SellerReviews                                                            3
# StreetName                                      25560 Madison Ave Murrieta
# State                                                                   CA
# Zipcode                                                              92562
# DealType                                                             Great
# ComfortRating                                                          4.7
# InteriorDesignRating                                                   4.6
# PerformanceRating                                                      4.6
# ValueForMoneyRating                                                    4.4
# ExteriorStylingRating                                                  4.6
# ReliabilityRating                                                      4.7
# ExteriorColor                                                          Red
# InteriorColor                                                        Black
# Drivetrain                                               Front-wheel Drive
# MinMPG                                                                  19
# MaxMPG                                                                  27
# FuelType                                                          Gasoline
# Transmission                                             8-Speed Automatic
# Engine                                                3.5L V6 24V PDI DOHC
# VIN                                                      5TDXZ3DC2KS015402
# Stock#                                                            22998646
# Mileage                                                              29403
# Name: 0, dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
df_trim_analysis = pd.read_csv('Online_Cars_Sale_Marketplace.csv')

# Define car type at the trim level
group_cols = ['Make', 'Model', 'Year', 'Trim']

# Group by Make + Model + Year + Trim
trim_summary = df_trim_analysis.groupby(group_cols).agg({
    'ConsumerReviews': 'sum',        # total number of reviews
    'ConsumerRating': 'mean',        # average rating
    'VIN': 'count'                   # number of listings
}).reset_index()

# Rename listing count column for clarity
trim_summary = trim_summary.rename(columns={'VIN': 'Listings'})

# Calculate square root of listings
trim_summary['SqrtListings'] = np.sqrt(trim_summary['Listings'])

# Compute the Popularity Score
trim_summary['PopularityScore'] = (
    trim_summary['ConsumerReviews'] *
    trim_summary['ConsumerRating'] *
    trim_summary['SqrtListings']
)

# Sort and get top 10 trims
top10_trims = trim_summary.sort_values(by='PopularityScore', ascending=False).head(10).copy()

# Create a label for plotting
top10_trims['CarLabel'] = (
    top10_trims['Year'].astype(str) + ' ' +
    top10_trims['Make'] + ' ' +
    top10_trims['Model'] + ' ' +
    top10_trims['Trim']
)

# Plot the results
plt.figure(figsize=(12, 6))
plt.barh(top10_trims['CarLabel'], top10_trims['PopularityScore'])
plt.gca().invert_yaxis()
plt.xlabel('Popularity Score (Rating × Reviews × sqrt(Listings))')
plt.title('Top 10 Most Popular Car Listings by Trim Level')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Display results table
print("Top 10 Most Popular Car Listings (Including Trim):")
print(top10_trims[['Year', 'Make', 'Model', 'Trim', 'PopularityScore']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 12
#       9 group_cols = ['Make', 'Model', 'Year', 'Trim']
#      11 # Group by Make + Model + Year + Trim
# ---> 12 trim_summary = df_trim_analysis.groupby(group_cols).agg({
#      13     'ConsumerReviews': 'sum',        # total number of reviews
#      14     'ConsumerRating': 'mean',        # average rating
#      15     'VIN': 'count'                   # number of listings
#      16 }).reset_index()
#      18 # Rename listing count column for clarity
#      19 trim_summary = trim_summary.rename(columns={'VIN': 'Listings'})
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'Trim'

# %%
# Step 1: Sort full grouped data by SqrtAdjustedPopularity in descending order
grouped_sorted_sqrt = grouped.sort_values(by='SqrtAdjustedPopularity', ascending=False)

# Step 2: Select the Top 10 cars
top10_sqrt = grouped_sorted_sqrt.head(10).copy()

# Step 3: Display the Top 10 scores in order
print("Top 10 Cars by Square Root Listings Adjusted Popularity Score (Descending Order):")
print(top10_sqrt[['Year', 'Make', 'Model', 'SqrtAdjustedPopularity']])
# Out:
# Top 10 Cars by Square Root Listings Adjusted Popularity Score (Descending Order):
#       Year      Make                   Model  SqrtAdjustedPopularity
# 1336  2019     Honda               CR-V EX-L            4.761808e+06
# 1335  2019     Honda                 CR-V EX            1.296122e+06
# 1390  2019      Jeep  Grand Cherokee Limited            1.206771e+06
# 1144  2018    Toyota                RAV4 XLE            7.327407e+05
# 1384  2019      Jeep        Cherokee Limited            7.111809e+05
# 1141  2018    Toyota                 RAV4 LE            7.006528e+05
# 1350  2019     Honda              Pilot EX-L            4.974770e+05
# 1252  2019  Cadillac              XT5 Luxury            4.520032e+05
# 1467  2019     Mazda      CX-5 Grand Touring            4.139750e+05
# 1023  2018      Jeep  Grand Cherokee Limited            3.272509e+05

# %%
import pandas as pd

# Load the dataset
dataf = pd.read_csv('Online_Cars_Sale_Marketplace.csv')

# View the first few rows
dataf.head()

# Get column data types and non-null counts
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9379 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9379 non-null   int64
#  1   Make                   9379 non-null   object
#  2   Model                  9379 non-null   object
#  3   Used/New               9379 non-null   object
#  4   Price                  9379 non-null   object
#  5   ConsumerRating         9379 non-null   float64
#  6   ConsumerReviews        9379 non-null   int64
#  7   SellerType             9379 non-null   object
#  8   SellerName             9379 non-null   object
#  9   SellerRating           9379 non-null   float64
#  10  SellerReviews          9379 non-null   int64
#  11  StreetName             9379 non-null   object
#  12  State                  9379 non-null   object
#  13  Zipcode                9379 non-null   object
#  14  DealType               9157 non-null   object
#  15  ComfortRating          9379 non-null   float64
#  16  InteriorDesignRating   9379 non-null   float64
#  17  PerformanceRating      9379 non-null   float64
#  18  ValueForMoneyRating    9379 non-null   float64
#  19  ExteriorStylingRating  9379 non-null   float64
#  20  ReliabilityRating      9379 non-null   float64
#  21  ExteriorColor          9379 non-null   object
#  22  InteriorColor          9379 non-null   object
#  23  Drivetrain             9379 non-null   object
#  24  MinMPG                 9379 non-null   int64
#  25  MaxMPG                 9379 non-null   int64
#  26  FuelType               9379 non-null   object
#  27  Transmission           9379 non-null   object
#  28  Engine                 9379 non-null   object
#  29  VIN                    9379 non-null   object
#  30  Stock#                 9379 non-null   object
#  31  Mileage                9379 non-null   int64
# dtypes: float64(8), int64(6), object(18)
# memory usage: 2.3+ MB

# %%
# Check missing values
dataf.isnull().sum()
# Out:
# Year                       0
# Make                       0
# Model                      0
# Used/New                   0
# Price                      0
# ConsumerRating             0
# ConsumerReviews            0
# SellerType                 0
# SellerName                 0
# SellerRating               0
# SellerReviews              0
# StreetName                 0
# State                      0
# Zipcode                    0
# DealType                 222
# ComfortRating              0
# InteriorDesignRating       0
# PerformanceRating          0
# ValueForMoneyRating        0
# ExteriorStylingRating      0
# ReliabilityRating          0
# ExteriorColor              0
# InteriorColor              0
# Drivetrain                 0
# MinMPG                     0
# MaxMPG                     0
# FuelType                   0
# Transmission               0
# Engine                     0
# VIN                        0
# Stock#                     0
# Mileage                    0
# dtype: int64

# %%
# Check duplicated rows
dataf.duplicated().sum()
# Out:
# 872

# %%
# Show unique DealType values
dataf['DealType'].unique()
# Out:
# array(['Great', 'Good', nan, 'Fair'], dtype=object)

# %%
# Show value counts for DealType
dataf['DealType'].value_counts()
# Out:
# DealType
# Good     5524
# Great    2408
# Fair     1225
# Name: count, dtype: int64

# %%
# Fill NaN values in DealType with 'Missing'
dataf['DealType'] = dataf['DealType'].fillna('Missing')

# Show unique DealType values
dataf['DealType'].unique()
# Out:
# array(['Great', 'Good', 'Missing', 'Fair'], dtype=object)

# %%
# Check duplicated rows
dataf.duplicated().sum()
# Out:
# 872

# %%
# View duplicated rows only
duplicated_rows = dataf[dataf.duplicated()]

# Show them
duplicated_rows
# Out:
#       Year           Make                Model            Used/New     Price  \
# 1645  2019          Buick     Encore Preferred                Used  $23,999
# 1701  2020          Tesla   Model Y Long Range                Used  $68,981
# 1723  2017         Subaru         Impreza 2.0i                Used  $16,823
# 1737  2019       INFINITI            QX80 Luxe                Used  $52,506
# 1766  2017  Mercedes-Benz  GLS 450 Base 4MATIC                Used  $44,995
# ...    ...            ...                  ...                 ...       ...
# 9245  2020       INFINITI            QX50 Luxe  INFINITI Certified  $36,205
# 9305  2015       Chrysler          200 Limited                Used   $4,250
# 9319  2017  Mercedes-Benz  GLS 450 Base 4MATIC                Used  $44,762
# 9335  2018           Ford         F-150 Lariat                Used  $47,989
# 9375  2019           Audi      Q8 3.0T Premium                Used  $61,998
#
#       ConsumerRating  ConsumerReviews SellerType  \
# 1645             4.7              182     Dealer
# 1701             3.7               10     Dealer
# 1723             4.8              175     Dealer
# 1737             4.8               26     Dealer
# 1766             4.9               37     Dealer
# ...              ...              ...        ...
# 9245             4.6               23     Dealer
# 9305             4.4              361     Dealer
# 9319             4.9               37     Dealer
# 9335             4.8              817     Dealer
# 9375             4.8               27     Dealer
#
#                                SellerName  SellerRating  ...  \
# 1645  AutoNation CDJR FIAT North Columbus           4.4  ...
# 1701                        Surprise Ford           2.8  ...
# 1723                        North Imports           4.5  ...
# 1737                     Ford of Franklin           4.8  ...
# 1766                AutoNation Ford Miami           4.7  ...
# ...                                   ...           ...  ...
# 9245                    INFINITI of Tampa           4.5  ...
# 9305                Texas Best Deal Autos           1.8  ...
# 9319                    Autohaus on Edens           4.7  ...
# 9335                        Carolina Ford           3.0  ...
# 9375             Autobahn USA Westborough           4.8  ...
#
#           InteriorColor         Drivetrain MinMPG MaxMPG  FuelType  \
# 1645                  –  Front-wheel Drive     25     30  Gasoline
# 1701              Black    All-wheel Drive    127    114  Electric
# 1723              Ivory    All-wheel Drive     28     38  Gasoline
# 1737       Saddle Brown   Rear-wheel Drive     14     20  Gasoline
# 1766                  –    All-wheel Drive     19     22  Gasoline
# ...                 ...                ...    ...    ...       ...
# 9245           Graphite  Front-wheel Drive     23     29  Gasoline
# 9305              Black  Front-wheel Drive     23     36  Gasoline
# 9319              Black    All-wheel Drive     19     22  Gasoline
# 9335  Medium Earth Gray   Four-wheel Drive     19     24  Gasoline
# 9375              Black    All-wheel Drive     17     22    Hybrid
#
#             Transmission                             Engine  \
# 1645   6-Speed Automatic        1.4L I4 16V MPFI DOHC Turbo
# 1701   1-Speed Automatic                           Electric
# 1723         CVT 7-Speed                  4 Cylinder Engine
# 1737   7-Speed Automatic               5.6L V8 32V GDI DOHC
# 1766   9-Speed Automatic    3.0L V6 24V GDI DOHC Twin Turbo
# ...                  ...                                ...
# 9245       Automatic CVT         2.0L I4 16V PDI DOHC Turbo
# 9305   9-Speed Automatic              2.4L I4 16V MPFI SOHC
# 9319   9-Speed Automatic    3.0L V6 24V GDI DOHC Twin Turbo
# 9335  10-Speed Automatic               5.0L V8 32V PDI DOHC
# 9375   8-Speed Automatic  3.0L V6 24V GDI DOHC Turbo Hybrid
#
#                     VIN      Stock#  Mileage
# 1645  KL4CJASB9KB761738    KB761738    19843
# 1701  5YJYGDEE2LF035154       P3392    15614
# 1723  4S3GKAA68H3601314        1314    40060
# 1737  JN8AZ2NF1K9688029    EL09626B    27017
# 1766  4JGDF6EE8HA966203    HA966203    36888
# ...                 ...         ...      ...
# 9245  3PCAJ5M18LF110978  CMT222436A    19123
# 9305  1C3CCCAB0FN698261      698261   119417
# 9319  4JGDF6EE7HA994803     62-810A    49001
# 9335  1FTEW1E53JFC09875       1462A    36000
# 9375  WA1AVAF14KD015389      AB4719    46855
#
# [872 rows x 32 columns]

# %%
# Show all duplicate groups (original and duplicate rows together)
duplicated_rows = dataf[dataf.duplicated(keep=False)]

# Display them
duplicated_rows.sort_values(by=list(dataf.columns)).reset_index(drop=True)
# Out:
#       Year    Make                      Model Used/New     Price  \
# 0     2004  Toyota            Highlander Base     Used   $5,995
# 1     2004  Toyota            Highlander Base     Used   $5,995
# 2     2005   Acura                MDX Touring     Used   $6,495
# 3     2005   Acura                MDX Touring     Used   $6,495
# 4     2007  Toyota                   Camry LE     Used   $9,950
# ...    ...     ...                        ...      ...       ...
# 1733  2022   Tesla         Model 3 Long Range     Used  $66,237
# 1734  2022  Toyota  Highlander Hybrid Limited     Used  $52,955
# 1735  2022  Toyota  Highlander Hybrid Limited     Used  $52,955
# 1736  2022   Volvo        XC60 B5 Inscription     Used  $48,500
# 1737  2022   Volvo        XC60 B5 Inscription     Used  $48,500
#
#       ConsumerRating  ConsumerReviews SellerType  \
# 0                4.5               47     Dealer
# 1                4.5               47     Dealer
# 2                4.7               54     Dealer
# 3                4.7               54     Dealer
# 4                4.2              301     Dealer
# ...              ...              ...        ...
# 1733             4.8                2     Dealer
# 1734             5.0                2     Dealer
# 1735             5.0                2     Dealer
# 1736             2.7                1     Dealer
# 1737             2.7                1     Dealer
#
#                             SellerName  SellerRating  ...  InteriorColor  \
# 0                 Northtown Auto Sales           4.9  ...            Tan
# 1                 Northtown Auto Sales           4.9  ...            Tan
# 2                            JP Motors           4.3  ...          Ebony
# 3                            JP Motors           4.3  ...          Ebony
# 4                         TJK AUTO LLC           4.1  ...            Tan
# ...                                ...           ...  ...            ...
# 1733  Napleton's Volkswagen of Sanford           4.6  ...          Black
# 1734         AutoNation Toyota Hayward           4.4  ...              –
# 1735         AutoNation Toyota Hayward           4.4  ...              –
# 1736        Volvo Cars Mall of Georgia           4.9  ...         Blonde
# 1737        Volvo Cars Mall of Georgia           4.9  ...         Blonde
#
#              Drivetrain MinMPG MaxMPG  FuelType       Transmission  \
# 0     Front-wheel Drive     23     23  Gasoline  Automatic 5-Speed
# 1     Front-wheel Drive     23     23  Gasoline  Automatic 5-Speed
# 2      Four-wheel Drive     17     23  Gasoline  5-Speed Automatic
# 3      Four-wheel Drive     17     23  Gasoline  5-Speed Automatic
# 4     Front-wheel Drive     22     31  Gasoline  6-Speed Automatic
# ...                 ...    ...    ...       ...                ...
# 1733    All-wheel Drive      0      0  Electric          Automatic
# 1734    All-wheel Drive     35     34    Hybrid      Automatic CVT
# 1735    All-wheel Drive     35     34    Hybrid      Automatic CVT
# 1736  Front-wheel Drive     23     30  Gasoline  8-Speed Automatic
# 1737  Front-wheel Drive     23     30  Gasoline  8-Speed Automatic
#
#                            Engine                VIN       Stock#  Mileage
# 0                         3.3L V6  JTEGP21A740039991  40039991STK   204440
# 1                         3.3L V6  JTEGP21A740039991  40039991STK   204440
# 2           3.5L V6 24V MPFI SOHC  2HNYD188X5H549256     2P771090   174916
# 3           3.5L V6 24V MPFI SOHC  2HNYD188X5H549256     2P771090   174916
# 4           3.5L V6 24V MPFI DOHC  4T1BK46K87U548913       548913    99223
# ...                           ...                ...          ...      ...
# 1733                     Electric  5YJ3E1EB0NF119495   ZNF119495P     2224
# 1734  2.5L I4 16V PDI DOHC Hybrid  5TDXBRCH7NS543753     NS543753    29994
# 1735  2.5L I4 16V PDI DOHC Hybrid  5TDXBRCH7NS543753     NS543753    29994
# 1736   2.0L I4 16V GDI DOHC Turbo  YV4L12DL6N1951540    LC422005B    18310
# 1737   2.0L I4 16V GDI DOHC Turbo  YV4L12DL6N1951540    LC422005B    18310
#
# [1738 rows x 32 columns]

# %%
# Drop exact duplicated rows
dataf = dataf.drop_duplicates()

# Reset index for cleanliness
dataf = dataf.reset_index(drop=True)

# Confirm no duplicates remain
print('Remaining duplicated rows:', dataf.duplicated().sum())
# Out:
# Remaining duplicated rows: 0

# %%
# Check how many VINs are duplicated
vin_duplicates = dataf[dataf['VIN'].duplicated(keep=False)]

# Show them sorted nicely
vin_duplicates.sort_values(by='VIN').reset_index(drop=True)
# Out:
#     Year           Make                   Model                 Used/New  \
# 0   2019           Jeep  Grand Cherokee Limited                     Used
# 1   2019           Jeep  Grand Cherokee Limited                     Used
# 2   2020            RAM        1500 Classic SLT                     Used
# 3   2020            RAM        1500 Classic SLT                     Used
# 4   2018           Ford            Explorer XLT                     Used
# ..   ...            ...                     ...                      ...
# 61  2019  Mercedes-Benz       AMG E 63 S 4MATIC  Mercedes-Benz Certified
# 62  2014          Volvo                  S60 T5                     Used
# 63  2014          Volvo                  S60 T5                     Used
# 64  2017           Alfa         Romeo Giulia Ti                     Used
# 65  2017           Alfa         Romeo Giulia Ti                     Used
#
#        Price  ConsumerRating  ConsumerReviews SellerType  \
# 0   $35,500              4.8              224     Dealer
# 1   $35,500              4.8              224     Dealer
# 2   $39,000              4.7               20     Dealer
# 3   $39,000              4.7               20     Dealer
# 4   $29,749              4.8              265     Dealer
# ..       ...             ...              ...        ...
# 61  $99,980              5.0                2     Dealer
# 62  $18,498              4.8               35     Dealer
# 63  $18,498              4.8               35     Dealer
# 64  $29,900              4.7               98    Private
# 65  $29,900              4.7               98    Private
#
#                                         SellerName  SellerRating  ...  \
# 0                               Scott Clark Toyota           4.7  ...
# 1                               Scott Clark Toyota           4.7  ...
# 2                         Nyhus Family Sales, Inc.           4.9  ...
# 3                         Nyhus Family Sales, Inc.           4.9  ...
# 4   EchoPark Automotive Greensboro Delivery Center           1.3  ...
# ..                                             ...           ...  ...
# 61                                House of Imports           4.7  ...
# 62                           Herb Connolly Hyundai           4.6  ...
# 63                           Herb Connolly Hyundai           4.6  ...
# 64                                             Tom           4.7  ...
# 65                                             Tom           4.5  ...
#
#           InteriorColor         Drivetrain MinMPG MaxMPG       FuelType  \
# 0                 Black   Four-wheel Drive     18     25       Gasoline
# 1                 Black   Four-wheel Drive     18     25       Gasoline
# 2   Diesel Gray / Black   Four-wheel Drive     16     23       Gasoline
# 3   Diesel Gray / Black   Four-wheel Drive     16     23       Gasoline
# 4           Ebony Black   Four-wheel Drive     16     22       Gasoline
# ..                  ...                ...    ...    ...            ...
# 61                    –    All-wheel Drive     15     23       Gasoline
# 62           Soft Beige  Front-wheel Drive     21     30       Gasoline
# 63           Soft Beige  Front-wheel Drive     21     30       Gasoline
# 64                Black    All-wheel Drive     23     31  Gasoline Fuel
# 65                Black    All-wheel Drive     23     31  Gasoline Fuel
#
#                       Transmission  \
# 0                8-Speed Automatic
# 1                8-Speed Automatic
# 2                8-Speed Automatic
# 3                8-Speed Automatic
# 4                6-Speed Automatic
# ..                             ...
# 61               9-Speed Automatic
# 62               6-Speed Automatic
# 63               6-Speed Automatic
# 64  Transmission w/Dual Shift Mode
# 65  Transmission w/Dual Shift Mode
#
#                                           Engine                VIN  \
# 0                          3.6L V6 24V MPFI DOHC  1C4RJFBG0KC555534
# 1                          3.6L V6 24V MPFI DOHC  1C4RJFBG0KC555534
# 2                          3.6L V6 24V MPFI DOHC  1C6RR7GGXLS109543
# 3                          3.6L V6 24V MPFI DOHC  1C6RR7GGXLS109543
# 4                          3.5L V6 24V MPFI DOHC  1FM5K8D87JGA12701
# ..                                           ...                ...
# 61               4.0L V8 32V GDI DOHC Twin Turbo  WDDZF8KB5KA547464
# 62                   2.5L I5 20V MPFI DOHC Turbo  YV1612FS5E1290176
# 63                   2.5L I5 20V MPFI DOHC Turbo  YV1612FS5E1290176
# 64  280.0HP 2.0L 4 Cylinder Engine Gasoline Fuel  ZARFAEEN7H7551320
# 65  280.0HP 2.0L 4 Cylinder Engine Gasoline Fuel  ZARFAEEN7H7551320
#
#        Stock#  Mileage
# 0     SH55534    32858
# 1     SH55534    32858
# 2      109543    13185
# 3      109543    13326
# 4   CJGA12701    48001
# ..        ...      ...
# 61   KA547464    19351
# 62   H024003A    55515
# 63   H024003A    55515
# 64          –    22855
# 65          –    22855
#
# [66 rows x 32 columns]

# %%
# Drop duplicated VINs, keep the first occurrence
dataf = dataf.drop_duplicates(subset='VIN', keep='first')

# Reset index for cleanliness
dataf = dataf.reset_index(drop=True)

# Double-check no VIN duplicates remain
print('Remaining duplicated VINs:', dataf['VIN'].duplicated().sum())
# Out:
# Remaining duplicated VINs: 0

# %%
# Create a cleaned copy
c_dataf = dataf.copy()

# %%
c_dataf
# Out:
#       Year     Make                   Model Used/New     Price  \
# 0     2019   Toyota               Sienna SE     Used  $39,998
# 1     2018     Ford            F-150 Lariat     Used  $49,985
# 2     2017      RAM            1500 Laramie     Used  $41,860
# 3     2021    Honda         Accord Sport SE     Used  $28,500
# 4     2020    Lexus                  RX 350     Used  $49,000
# ...    ...      ...                     ...      ...       ...
# 8469  2019    Honda               CR-V EX-L     Used  $31,999
# 8470  2019   Subaru  Crosstrek 2.0i Premium     Used  $27,374
# 8471  2017    Buick         Enclave Leather     Used  $26,944
# 8472  2019   Subaru        Forester Premium     Used  $28,568
# 8473  2019  Hyundai   Santa Fe Ultimate 2.4     Used  $32,091
#
#       ConsumerRating  ConsumerReviews SellerType  \
# 0                4.6               45     Dealer
# 1                4.8              817     Dealer
# 2                4.7              495     Dealer
# 3                5.0               36     Dealer
# 4                4.8               76     Dealer
# ...              ...              ...        ...
# 8469             4.8              540     Dealer
# 8470             4.7              205     Dealer
# 8471             4.8              137     Dealer
# 8472             4.7              279     Dealer
# 8473             4.8              204     Dealer
#
#                                              SellerName  SellerRating  ...  \
# 0     CarMax Murrieta - Now offering Curbside Pickup...           3.3  ...
# 1                                       Giant Chevrolet           4.8  ...
# 2                                Gill Auto Group Madera           4.6  ...
# 3                                   AutoSavvy Las Vegas           4.6  ...
# 4                                    Lexus of Henderson           4.8  ...
# ...                                                 ...           ...  ...
# 8469                                      Hoffman Honda           4.8  ...
# 8470                 Bertera Subaru of West Springfield           4.4  ...
# 8471                            Tulley Automotive Group           4.7  ...
# 8472                                         Ira Subaru           4.4  ...
# 8473                                   Route 44 Hyundai           4.4  ...
#
#       InteriorColor         Drivetrain MinMPG MaxMPG  FuelType  \
# 0             Black  Front-wheel Drive     19     27  Gasoline
# 1             Black   Four-wheel Drive     19     24  Gasoline
# 2             Black   Four-wheel Drive     15     21  Gasoline
# 3                 –  Front-wheel Drive     29     35  Gasoline
# 4             Birch  Front-wheel Drive     20     27  Gasoline
# ...             ...                ...    ...    ...       ...
# 8469              –    All-wheel Drive     27     33  Gasoline
# 8470           Gray    All-wheel Drive     27     33  Gasoline
# 8471          Ebony    All-wheel Drive     15     22  Gasoline
# 8472          Black    All-wheel Drive     26     33  Gasoline
# 8473          Black    All-wheel Drive     21     27  Gasoline
#
#             Transmission                           Engine                VIN  \
# 0      8-Speed Automatic             3.5L V6 24V PDI DOHC  5TDXZ3DC2KS015402
# 1     10-Speed Automatic  3.5L V6 24V PDI DOHC Twin Turbo  1FTEW1EG2JFD44217
# 2      8-Speed Automatic             5.7L V8 16V MPFI OHV  1C6RR7VT5HS842283
# 3          Automatic CVT       1.5L I4 16V GDI DOHC Turbo  1HGCV1F49MA038035
# 4      8-Speed Automatic             3.5L V6 24V PDI DOHC  2T2AZMAA8LC156270
# ...                  ...                              ...                ...
# 8469       Automatic CVT       1.5L I4 16V GDI DOHC Turbo  2HKRW2H87KH643043
# 8470       Automatic CVT             2.0L H4 16V GDI DOHC  JF2GTADC4KH318032
# 8471   6-Speed Automatic             3.6L V6 24V GDI DOHC  5GAKVBKD4HJ190334
# 8472       Automatic CVT             2.5L H4 16V GDI DOHC  JF2SKAGC9KH423450
# 8473   8-Speed Automatic             2.4L I4 16V GDI DOHC  5NMS5CAD1KH002128
#
#          Stock#  Mileage
# 0      22998646    29403
# 1        22418A    32929
# 2     NG277871G    23173
# 3         54237    10598
# 4      HDT4181A    28137
# ...         ...      ...
# 8469    10553HB    44481
# 8470    220502A    15606
# 8471   B221381B    62649
# 8472   KH423450    30760
# 8473     H48345    41645
#
# [8474 rows x 32 columns]

# %%
# List all columns with 'Rating' in their name
rating_columns = [col for col in c_dataf.columns if 'Rating' in col]

# Show them
rating_columns
# Out:
# ['ConsumerRating',
#  'SellerRating',
#  'ComfortRating',
#  'InteriorDesignRating',
#  'PerformanceRating',
#  'ValueForMoneyRating',
#  'ExteriorStylingRating',
#  'ReliabilityRating']

# %%
# Display only the columns that have 'Rating' in their name
c_dataf[rating_columns].head()
# Out:
#    ConsumerRating  SellerRating  ComfortRating  InteriorDesignRating  \
# 0             4.6           3.3            4.7                   4.6
# 1             4.8           4.8            4.9                   4.8
# 2             4.7           4.6            4.8                   4.7
# 3             5.0           4.6            4.9                   5.0
# 4             4.8           4.8            4.9                   4.8
#
#    PerformanceRating  ValueForMoneyRating  ExteriorStylingRating  \
# 0                4.6                  4.4                    4.6
# 1                4.8                  4.6                    4.8
# 2                4.8                  4.6                    4.8
# 3                4.9                  5.0                    5.0
# 4                4.8                  4.7                    4.8
#
#    ReliabilityRating
# 0                4.7
# 1                4.7
# 2                4.7
# 3                5.0
# 4                4.9

# %%
# 1. Find all Rating columns
rating_columns = [col for col in c_dataf.columns if 'Rating' in col]

# 2. Group by Year, Make, Model and take the mean of rating columns
grouped_ratings = c_dataf.groupby(['Year', 'Make', 'Model'])[rating_columns].mean().reset_index()

# 3. Create a new column: Super_Avg_Rating = average of all rating columns
grouped_ratings['Super_Avg_Rating'] = grouped_ratings[rating_columns].mean(axis=1)

# 4. Sort by Super_Avg_Rating descending (highest first)
top_cars_by_super_rating = grouped_ratings.sort_values(by='Super_Avg_Rating', ascending=False)

# 5. Show top 10
top_cars_by_super_rating.head(10)
# Out:
#       Year           Make                         Model  ConsumerRating  \
# 1436  2019          Lexus                   LC 500 Base             5.0
# 2412  2021          Volvo  XC90 T5 Momentum 7 Passenger             5.0
# 2152  2021           Ford            Expedition Limited             5.0
# 2424  2022      Chevrolet                      Tahoe LT             5.0
# 1884  2020          Lexus                GS 350 F Sport             5.0
# 2270  2021        Lincoln         Navigator Black Label             5.0
# 1929  2020  Mercedes-Benz          E-Class E 450 4MATIC             5.0
# 2113  2021       Cadillac   Escalade ESV Premium Luxury             5.0
# 1664  2020            BMW                         740 i             5.0
# 1919  2020  Mercedes-Benz                 A-Class A 220             5.0
#
#       SellerRating  ComfortRating  InteriorDesignRating  PerformanceRating  \
# 1436          4.90            5.0                   5.0                5.0
# 2412          4.90            5.0                   5.0                5.0
# 2152          4.90            5.0                   5.0                5.0
# 2424          4.80            5.0                   5.0                5.0
# 1884          4.80            5.0                   5.0                5.0
# 2270          4.80            5.0                   5.0                5.0
# 1929          4.80            5.0                   5.0                5.0
# 2113          4.80            5.0                   5.0                5.0
# 1664          4.75            5.0                   5.0                5.0
# 1919          4.70            5.0                   5.0                5.0
#
#       ValueForMoneyRating  ExteriorStylingRating  ReliabilityRating  \
# 1436                  5.0                    5.0                5.0
# 2412                  5.0                    5.0                5.0
# 2152                  5.0                    5.0                5.0
# 2424                  5.0                    5.0                5.0
# 1884                  5.0                    5.0                5.0
# 2270                  5.0                    5.0                5.0
# 1929                  5.0                    5.0                5.0
# 2113                  5.0                    5.0                5.0
# 1664                  5.0                    5.0                5.0
# 1919                  5.0                    5.0                5.0
#
#       Super_Avg_Rating
# 1436           4.98750
# 2412           4.98750
# 2152           4.98750
# 2424           4.97500
# 1884           4.97500
# 2270           4.97500
# 1929           4.97500
# 2113           4.97500
# 1664           4.96875
# 1919           4.96250

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9379 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9379 non-null   int64
#  1   Make                   9379 non-null   object
#  2   Model                  9379 non-null   object
#  3   Used/New               9379 non-null   object
#  4   Price                  9374 non-null   float64
#  5   ConsumerRating         9379 non-null   float64
#  6   ConsumerReviews        9379 non-null   int64
#  7   SellerType             9379 non-null   object
#  8   SellerName             9379 non-null   object
#  9   SellerRating           9379 non-null   float64
#  10  SellerReviews          9379 non-null   int64
#  11  StreetName             9379 non-null   object
#  12  State                  9379 non-null   object
#  13  Zipcode                9379 non-null   object
#  14  DealType               9157 non-null   object
#  15  ComfortRating          9379 non-null   float64
#  16  InteriorDesignRating   9379 non-null   float64
#  17  PerformanceRating      9379 non-null   float64
#  18  ValueForMoneyRating    9379 non-null   float64
#  19  ExteriorStylingRating  9379 non-null   float64
#  20  ReliabilityRating      9379 non-null   float64
#  21  ExteriorColor          9379 non-null   object
#  22  InteriorColor          9379 non-null   object
#  23  Drivetrain             9379 non-null   object
#  24  MinMPG                 9379 non-null   int64
#  25  MaxMPG                 9379 non-null   int64
#  26  FuelType               9379 non-null   object
#  27  Transmission           9379 non-null   object
#  28  Engine                 9379 non-null   object
#  29  VIN                    9379 non-null   object
#  30  Stock#                 9379 non-null   object
#  31  Mileage                9379 non-null   int64
# dtypes: float64(9), int64(6), object(17)
# memory usage: 2.3+ MB

# %%
# 1. Find all Review columns
review_columns = [col for col in c_dataf.columns if 'Review' in col or 'Reviews' in col]

# 2. Group by Year, Make, Model and sum the review columns
grouped_reviews = c_dataf.groupby(['Year', 'Make', 'Model'])[review_columns].sum().reset_index()

# 3. Create a new column: Total_Reviews = sum of all review columns
grouped_reviews['Total_Reviews'] = grouped_reviews[review_columns].sum(axis=1)

# 4. Sort by Total_Reviews descending (highest first)
top_cars_by_reviews = grouped_reviews.sort_values(by='Total_Reviews', ascending=False)

# 5. Show top 10
top_cars_by_reviews.head(10)
# Out:
#       Year      Make                   Model  ConsumerReviews  SellerReviews  \
# 1336  2019     Honda               CR-V EX-L            67500         222638
# 1390  2019      Jeep  Grand Cherokee Limited            21280         128033
# 1335  2019     Honda                 CR-V EX            30240          83562
# 1232  2019       BMW            X5 xDrive40i             5445          90042
# 1384  2019      Jeep        Cherokee Limited            21016          68521
# 1252  2019  Cadillac              XT5 Luxury             7990          71891
# 1350  2019     Honda              Pilot EX-L            10927          62758
# 1841  2020      Jeep  Grand Cherokee Limited             6750          62214
# 1144  2018    Toyota                RAV4 XLE            20790          44975
# 1141  2018    Toyota                 RAV4 LE            23870          38498
#
#       Total_Reviews
# 1336         290138
# 1390         149313
# 1335         113802
# 1232          95487
# 1384          89537
# 1252          79881
# 1350          73685
# 1841          68964
# 1144          65765
# 1141          62368

# %%
# 1. Group by Year, Make, Model and sum ConsumerReviews
grouped_consumer_reviews = c_dataf.groupby(['Year', 'Make', 'Model'])['ConsumerReviews'].sum().reset_index()

# 2. Sort by ConsumerReviews descending (highest first)
top_cars_by_consumer_reviews = grouped_consumer_reviews.sort_values(by='ConsumerReviews', ascending=False)

# 3. Show top 10
top_cars_by_consumer_reviews.head(10)
# Out:
#       Year    Make                   Model  ConsumerReviews
# 1336  2019   Honda               CR-V EX-L            67500
# 1335  2019   Honda                 CR-V EX            30240
# 1141  2018  Toyota                 RAV4 LE            23870
# 1390  2019    Jeep  Grand Cherokee Limited            21280
# 1384  2019    Jeep        Cherokee Limited            21016
# 1144  2018  Toyota                RAV4 XLE            20790
# 1023  2018    Jeep  Grand Cherokee Limited            11850
# 1350  2019   Honda              Pilot EX-L            10927
# 969   2018    Ford            F-150 Lariat            10621
# 1467  2019   Mazda      CX-5 Grand Touring             9890

# %%
# 1. Group by Year, Make, Model and average ConsumerRating
grouped_consumer_rating = c_dataf.groupby(['Year', 'Make', 'Model'])['ConsumerRating'].mean().reset_index()

# 2. Sort by ConsumerRating descending (highest first)
top_cars_by_consumer_rating = grouped_consumer_rating.sort_values(by='ConsumerRating', ascending=False)

# 3. Show top 10
top_cars_by_consumer_rating.head(90)
# Out:
#       Year     Make                       Model  ConsumerRating
# 1958  2020   Nissan               Maxima 3.5 SR             5.0
# 2181  2021    Honda           Accord Sport 2.0T             5.0
# 2461  2022   Toyota                  Corolla LE             5.0
# 1779  2020      GMC          Sierra 3500 Denali             5.0
# 1316  2019     Ford            Transit-250 Base             5.0
# ...    ...      ...                         ...             ...
# 1762  2020     Ford      Fusion Hybrid Titanium             5.0
# 1658  2020     Audi  Q7 55 quattro Premium Plus             5.0
# 2430  2022    Honda                 Civic Sport             5.0
# 2428  2022  Genesis             GV70 3.5T Sport             5.0
# 2436  2022  Hyundai                  IONIQ 5 SE             5.0
#
# [90 rows x 4 columns]

# %%
# Check unique values in 'Used/New' column
c_dataf['Used/New'].unique()
# Out:
# array(['Used', 'Dodge Certified', 'Acura Certified', 'Honda Certified',
#        'Mercedes-Benz Certified', 'Ford Certified', 'Toyota Certified',
#        'BMW Certified', 'Porsche Certified', 'Cadillac Certified',
#        'Volvo Certified', 'Nissan Certified', 'Subaru Certified',
#        'Volkswagen Certified', 'INFINITI Certified',
#        'Chevrolet Certified', 'Kia Certified', 'RAM Certified',
#        'Jeep Certified', 'GMC Certified', 'Buick Certified',
#        'Alfa Romeo Certified', 'Bentley Certified', 'MINI Certified',
#        'Ferrari Certified', 'Maserati Certified'], dtype=object)

# %%
# Rename 'Used/New' column to 'Used/Certified Used'
c_dataf = c_dataf.rename(columns={'Used/New': 'Used/Certified Used'})

# Double-check
c_dataf['Used/Certified Used'].unique()
# Out:
# array(['Used', 'Dodge Certified', 'Acura Certified', 'Honda Certified',
#        'Mercedes-Benz Certified', 'Ford Certified', 'Toyota Certified',
#        'BMW Certified', 'Porsche Certified', 'Cadillac Certified',
#        'Volvo Certified', 'Nissan Certified', 'Subaru Certified',
#        'Volkswagen Certified', 'INFINITI Certified',
#        'Chevrolet Certified', 'Kia Certified', 'RAM Certified',
#        'Jeep Certified', 'GMC Certified', 'Buick Certified',
#        'Alfa Romeo Certified', 'Bentley Certified', 'MINI Certified',
#        'Ferrari Certified', 'Maserati Certified'], dtype=object)

# %%
# 1. Group necessary columns
grouped_scores = c_dataf.groupby(['Year', 'Make', 'Model']).agg({
    'ConsumerRating': 'mean',
    'ConsumerReviews': 'sum',
    'SellerRating': 'mean',
    'SellerReviews': 'sum'
}).reset_index()

# 2. Create Consumer Popularity Score
grouped_scores['Consumer_Popularity_Score'] = grouped_scores['ConsumerRating'] * grouped_scores['ConsumerReviews']

# 3. Create Seller Popularity Score
grouped_scores['Seller_Popularity_Score'] = grouped_scores['SellerRating'] * grouped_scores['SellerReviews']

# 4. Sort the table in **descending** order by Consumer_Popularity_Score
grouped_scores = grouped_scores.sort_values(by='Consumer_Popularity_Score', ascending=False).reset_index(drop=True)

# 5. View the first few rows
grouped_scores.head(20)
# Out:
#     Year      Make                   Model  ConsumerRating  ConsumerReviews  \
# 0   2019     Honda               CR-V EX-L             4.8            67500
# 1   2019     Honda                 CR-V EX             4.8            30240
# 2   2018    Toyota                 RAV4 LE             4.8            23870
# 3   2019      Jeep  Grand Cherokee Limited             4.8            21280
# 4   2018    Toyota                RAV4 XLE             4.8            20790
# 5   2019      Jeep        Cherokee Limited             4.6            21016
# 6   2018      Jeep  Grand Cherokee Limited             4.8            11850
# 7   2019     Honda              Pilot EX-L             4.8            10927
# 8   2018      Ford            F-150 Lariat             4.8            10621
# 9   2019     Mazda      CX-5 Grand Touring             4.8             9890
# 10  2019      Ford               F-150 XLT             4.8             8500
# 11  2019       RAM            1500 Laramie             4.7             8532
# 12  2019    Toyota          Highlander XLE             4.6             8712
# 13  2019    Toyota                 RAV4 LE             4.6             8436
# 14  2018    Toyota            RAV4 Limited             4.8             7700
# 15  2019  Cadillac              XT5 Luxury             4.6             7990
# 16  2018      Ford               Escape SE             4.7             7514
# 17  2017      Jeep  Grand Cherokee Limited             4.8             7348
# 18  2020      Jeep  Grand Cherokee Limited             4.8             6750
# 19  2020       RAM            1500 Laramie             4.8             6030
#
#     SellerRating  SellerReviews  Consumer_Popularity_Score  \
# 0       4.605600         222638                   324000.0
# 1       4.637500          83562                   145152.0
# 2       4.493548          38498                   114576.0
# 3       4.453684         128033                   102144.0
# 4       4.437037          44975                    99792.0
# 5       4.264865          68521                    96673.6
# 6       4.426667          27175                    56880.0
# 7       4.604082          62758                    52449.6
# 8       4.176923          26634                    50980.8
# 9       4.565116          28719                    47472.0
# 10      4.245000          10996                    40800.0
# 11      3.961111          12595                    40100.4
# 12      4.554167          21956                    40075.2
# 13      4.468421          29156                    38805.6
# 14      4.260000          15601                    36960.0
# 15      4.502353          71891                    36754.0
# 16      4.115385           7713                    35315.8
# 17      4.490909          12783                    35270.4
# 18      4.553333          62214                    32400.0
# 19      4.556667          34975                    28944.0
#
#     Seller_Popularity_Score
# 0              1.025382e+06
# 1              3.875188e+05
# 2              1.729926e+05
# 3              5.702186e+05
# 4              1.995557e+05
# 5              2.922328e+05
# 6              1.202947e+05
# 7              2.889430e+05
# 8              1.112482e+05
# 9              1.311056e+05
# 10             4.667802e+04
# 11             4.989019e+04
# 12             9.999128e+04
# 13             1.302813e+05
# 14             6.646026e+04
# 15             3.236787e+05
# 16             3.174196e+04
# 17             5.740729e+04
# 18             2.832811e+05
# 19             1.593694e+05

# %%
# 1. Create a Total Popularity Score
grouped_scores['Total_Popularity_Score'] = grouped_scores['Consumer_Popularity_Score'] + grouped_scores['Seller_Popularity_Score']

# 2. Sort by Total Popularity Score in descending order
grouped_scores = grouped_scores.sort_values(by='Total_Popularity_Score', ascending=False).reset_index(drop=True)

# 3. View the top 10
grouped_scores[['Year', 'Make', 'Model', 'Total_Popularity_Score']].head(10)
# Out:
#    Year      Make                   Model  Total_Popularity_Score
# 0  2019     Honda               CR-V EX-L            1.349382e+06
# 1  2019      Jeep  Grand Cherokee Limited            6.723626e+05
# 2  2019     Honda                 CR-V EX            5.326708e+05
# 3  2019       BMW            X5 xDrive40i            4.315991e+05
# 4  2019      Jeep        Cherokee Limited            3.889064e+05
# 5  2019  Cadillac              XT5 Luxury            3.604327e+05
# 6  2019     Honda              Pilot EX-L            3.413926e+05
# 7  2020      Jeep  Grand Cherokee Limited            3.156811e+05
# 8  2018    Toyota                RAV4 XLE            2.993477e+05
# 9  2018    Toyota                 RAV4 LE            2.875686e+05

# %%
# 1. Group necessary columns
grouped_scores = c_dataf.groupby(['Year', 'Make', 'Model']).agg({
    'ConsumerRating': 'mean',
    'ConsumerReviews': 'sum',
    'SellerRating': 'mean',
    'SellerReviews': 'sum',
    'Used/Certified Used': lambda x: x.mode()[0]  # Get the most common value
}).reset_index()

# 2. Create Consumer Popularity Score
grouped_scores['Consumer_Popularity_Score'] = grouped_scores['ConsumerRating'] * grouped_scores['ConsumerReviews']

# 3. Create Seller Popularity Score
grouped_scores['Seller_Popularity_Score'] = grouped_scores['SellerRating'] * grouped_scores['SellerReviews']

# 4. Create Total Popularity Score
grouped_scores['Total_Popularity_Score'] = grouped_scores['Consumer_Popularity_Score'] + grouped_scores['Seller_Popularity_Score']

# 5. Sort by Total Popularity Score in descending order
grouped_scores = grouped_scores.sort_values(by='Total_Popularity_Score', ascending=False).reset_index(drop=True)

# 6. View top 10
grouped_scores[['Year', 'Make', 'Model', 'Used/Certified Used', 'Total_Popularity_Score']].head(10)
# Out:
#    Year      Make                   Model Used/Certified Used  \
# 0  2019     Honda               CR-V EX-L     Honda Certified
# 1  2019      Jeep  Grand Cherokee Limited                Used
# 2  2019     Honda                 CR-V EX                Used
# 3  2019       BMW            X5 xDrive40i                Used
# 4  2019      Jeep        Cherokee Limited                Used
# 5  2019  Cadillac              XT5 Luxury                Used
# 6  2019     Honda              Pilot EX-L                Used
# 7  2020      Jeep  Grand Cherokee Limited                Used
# 8  2018    Toyota                RAV4 XLE                Used
# 9  2018    Toyota                 RAV4 LE                Used
#
#    Total_Popularity_Score
# 0            1.349382e+06
# 1            6.723626e+05
# 2            5.326708e+05
# 3            4.315991e+05
# 4            3.889064e+05
# 5            3.604327e+05
# 6            3.413926e+05
# 7            3.156811e+05
# 8            2.993477e+05
# 9            2.875686e+05

# %%
grouped_scores.head(1)
# Out:
#    Year   Make      Model  ConsumerRating  ConsumerReviews  SellerRating  \
# 0  2019  Honda  CR-V EX-L             4.8            67500        4.6056
#
#    SellerReviews Used/Certified Used  Consumer_Popularity_Score  \
# 0         222638     Honda Certified                   324000.0
#
#    Seller_Popularity_Score  Total_Popularity_Score
# 0             1.025382e+06            1.349382e+06
