# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
car_sales = pd.read_csv(r"C:\Users\shayj\Downloads\Online_Cars_Sale_Marketplace (2).csv")

# %%
car_sales
# Out:
#       Year     Make          Model Used/New      Price  ConsumerRating  \
# 0     2021  Porsche            911     Used  $157,993              4.9
# 1     2010      BMW       128 128i     Used    $8,999              4.7
# 2     2021      RAM  1500 Big Horn     Used   $49,997              4.8
# 3     2021      RAM  1500 Big Horn     Used   $42,548              4.8
# 4     2021      RAM  1500 Big Horn     Used   $41,623              4.8
# ...    ...      ...            ...      ...        ...             ...
# 9374  2019      BMW   Z4 sDrive30i     Used   $46,500              5.0
# 9375  2019      BMW   Z4 sDrive30i     Used   $46,500              5.0
# 9376  2014      BMW   Z4 sDrive35i     Used   $34,500              4.9
# 9377  2015      BMW  Z4 sDrive35is     Used   $49,400              4.6
# 9378  2003     Ford            ZX2     Used    $6,995              4.0
#
#       ConsumerReviews SellerType                                SellerName  \
# ...

# %%
car_sales.head()
# Out:
#    Year     Make          Model Used/New      Price  ConsumerRating  \
# 0  2021  Porsche            911     Used  $157,993              4.9
# 1  2010      BMW       128 128i     Used    $8,999              4.7
# 2  2021      RAM  1500 Big Horn     Used   $49,997              4.8
# 3  2021      RAM  1500 Big Horn     Used   $42,548              4.8
# 4  2021      RAM  1500 Big Horn     Used   $41,623              4.8
#
#    ConsumerReviews SellerType                                SellerName  \
# 0                4     Dealer                             Porsche Marin
# 1               10     Dealer                        A & H Quality Cars
# 2               92     Dealer  Posner Park Chrysler Dodge Jeep Ram Fiat
# 3               92     Dealer                      Kia of Wesley Chapel
# 4               92     Dealer                    Greenway Nissan Venice
#
#    SellerRating  ...         InteriorColor        Drivetrain MinMPG MaxMPG  \
# ...

# %%
car_sales.dtypes
# Out:
# Year                       int64
# Make                      object
# Model                     object
# Used/New                  object
# Price                     object
# ConsumerRating           float64
# ConsumerReviews            int64
# SellerType                object
# SellerName                object
# SellerRating             float64
# SellerReviews              int64
# StreetName                object
# State                     object
# Zipcode                   object
# DealType                  object
# ComfortRating            float64
# InteriorDesignRating     float64
# PerformanceRating        float64
# ValueForMoneyRating      float64
# ExteriorStylingRating    float64
# ReliabilityRating        float64
# ExteriorColor             object
# InteriorColor             object
# Drivetrain                object
# MinMPG                     int64
# MaxMPG                     int64
# FuelType                  object
# Transmission              object
# ...

# %%
car_sales.describe()
# Out:
#               Year  ConsumerRating  ConsumerReviews  SellerRating  \
# count  9379.000000     9379.000000      9379.000000   9379.000000
# mean   2018.721719        4.702825       133.187014      4.412571
# std       2.221708        0.240795       154.985640      0.626258
# min    2001.000000        2.500000         1.000000      1.000000
# 25%    2018.000000        4.700000        30.000000      4.300000
# 50%    2019.000000        4.800000        75.000000      4.600000
# 75%    2020.000000        4.800000       182.000000      4.800000
# max    2022.000000        5.000000       817.000000      5.000000
#
#        SellerReviews  ComfortRating  InteriorDesignRating  PerformanceRating  \
# count    9379.000000    9379.000000           9379.000000        9379.000000
# mean      984.089988       4.771895              4.727391           4.696290
# std      1609.039864       0.217822              0.194391           0.253664
# ...

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9379 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9379 non-null   int64
#  1   Make                   9379 non-null   object
#  2   Model                  9379 non-null   object
#  3   Used/New               9379 non-null   object
#  4   Price                  9379 non-null   object
#  5   ConsumerRating         9379 non-null   float64
#  6   ConsumerReviews        9379 non-null   int64
#  7   SellerType             9379 non-null   object
#  8   SellerName             9379 non-null   object
#  9   SellerRating           9379 non-null   float64
#  10  SellerReviews          9379 non-null   int64
#  11  StreetName             9379 non-null   object
#  12  State                  9379 non-null   object
#  13  Zipcode                9379 non-null   object
# ...

# %%
car_prices = car_sales['Price']
car_prices
average_price = car_prices.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 car_prices = car_sales['Price']
#       2 car_prices
# ----> 3 average_price = car_prices.mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
# ...

# %%
car_prices.value_counts()
# Out:
# Price
# $29,995     36
# $42,998     30
# $38,998     29
# $31,998     29
# $39,998     28
#             ..
# $32,923      1
# $30,774      1
# $28,241      1
# $29,139      1
# $53,063      1
# Name: count, Length: 5064, dtype: int64

# %%
car_prices.sort_values()
# Out:
# 3042      $10,499
# 8022      $10,775
# 2719      $10,795
# 9003      $10,795
# 8127      $10,799
#            ...
# 503     Not Priced
# 1594    Not Priced
# 1584    Not Priced
# 1466    Not Priced
# 2088    Not Priced
# Name: Price, Length: 9379, dtype: object

# %%
car_sales['Price'].max()
# Out:
# 'Not Priced'

# %% [markdown]
# 3/20/2025 Today I was exploring the data more and trying to clean it a little bit, but that's going to require some more time to work. I was trying to get average car prices in the data set, and there were issues with float, so that's something I have to go back to. Even though that was an issue, I did car_prices.value_counts(), and from that data, the most common price for the cars in the data set is 29,995 which is helpful to know. By doing sort values, I also saw the cheapest cars are around 10,000. Another observation is that some cars aren't priced; when I was trying to figure out the most expensive car in the data set, I got that. When loading car_sales.info(), I noticed there are all different data types like float, object, and int. Beside trying to clean data, I was quite surprised with the amount of different columns that were in car_sales.info(). I will continue to go over the data and make more observations, but for now this is what I have picked up

# %% [markdown]
# Progress for Justin Shay for group project. test
#
# 3/15/2025
#
# added my folder to my branch
#
# 3/20/2025
#
# Did some more changes to my data workspace and added some more things on there
